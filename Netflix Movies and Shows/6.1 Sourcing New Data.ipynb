# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
df_orig = pd.read_csv(r"C:\Users\danie\Desktop\Dan\Career Foundry\Achievement Six\Netflix Movies and Shows\imdb_movies_shows.csv")

# %%
path = r'C:\Users\danie\Desktop\Dan\Career Foundry\Achievement Six\Netflix Movies and Shows\imdb_movies_shows.csv'

# %%
path
# Out:
# 'C:\\Users\\danie\\Desktop\\Dan\\Career Foundry\\Achievement Six\\Netflix Movies and Shows\\imdb_movies_shows.csv'

# %%
df_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5806 entries, 0 to 5805
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 5805 non-null   object
#  1   type                  5806 non-null   object
#  2   release_year          5806 non-null   int64
#  3   age_certification     3196 non-null   object
#  4   runtime               5806 non-null   int64
#  5   genres                5806 non-null   object
#  6   production_countries  5806 non-null   object
#  7   seasons               2047 non-null   float64
#  8   imdb_id               5362 non-null   object
#  9   imdb_score            5283 non-null   float64
#  10  imdb_votes            5267 non-null   float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 499.1+ KB

# %%
df_orig.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes
# count   5806.000000  5806.000000  2047.000000  5283.000000  5.267000e+03
# mean    2016.013434    77.643989     2.165608     6.533447  2.340719e+04
# std        7.324883    39.474160     2.636207     1.160932  8.713432e+04
# min     1945.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2015.000000    44.000000     1.000000     5.800000  5.210000e+02
# 50%     2018.000000    84.000000     1.000000     6.600000  2.279000e+03
# 75%     2020.000000   105.000000     2.000000     7.400000  1.014400e+04
# max     2022.000000   251.000000    42.000000     9.600000  2.268288e+06

# %%
df_orig.head()
# Out:
#                                  title   type  release_year age_certification  \
# 0  Five Came Back: The Reference Films   SHOW          1945             TV-MA
# 1                          Taxi Driver  MOVIE          1976                 R
# 2      Monty Python and the Holy Grail  MOVIE          1975                PG
# 3                        Life of Brian  MOVIE          1979                 R
# 4                         The Exorcist  MOVIE          1973                 R
#
#    runtime                 genres production_countries  seasons    imdb_id  \
# 0       48      ['documentation']               ['US']      1.0        NaN
# 1      113     ['crime', 'drama']               ['US']      NaN  tt0075314
# 2       91  ['comedy', 'fantasy']               ['GB']      NaN  tt0071853
# 3       94             ['comedy']               ['GB']      NaN  tt0079470
# 4      133             ['horror']               ['US']      NaN  tt0070047
#
#    imdb_score  imdb_votes
# ...

# %%
df_orig.isnull().sum()
# Out:
# title                      1
# type                       0
# release_year               0
# age_certification       2610
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3759
# imdb_id                  444
# imdb_score               523
# imdb_votes               539
# dtype: int64

# %%
# Drop the NAN 
df_orig.dropna(subset = ['imdb_score'], inplace = True)

# %%
df_orig.isnull().sum()
# Out:
# title                      0
# type                       0
# release_year               0
# age_certification       2285
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3407
# imdb_id                    0
# imdb_score                 0
# imdb_votes                16
# dtype: int64

# %%
# Drop the NAN 
df_orig.dropna(subset = ['age_certification'], inplace = True)

# %%
# Drop the NAN 
df_orig.dropna(subset = ['seasons'], inplace = True)

# %%
# Drop seasons column from data set
df_orig.drop(columns = ['seasons'])
# Out:
#                                  title  type  release_year age_certification  \
# 5         Monty Python's Flying Circus  SHOW          1969             TV-14
# 29    Monty Python's Fliegender Zirkus  SHOW          1972             TV-MA
# 47                            Seinfeld  SHOW          1989             TV-PG
# 55                        Knight Rider  SHOW          1982             TV-PG
# 57                    Thomas & Friends  SHOW          1984              TV-Y
# ...                                ...   ...           ...               ...
# 5758          Abla Fahita: Drama Queen  SHOW          2021             TV-14
# 5768                    Christmas Flow  SHOW          2021             TV-MA
# 5770       Korean Cold Noodle Rhapsody  SHOW          2021             TV-PG
# 5785                     Pitta Kathalu  SHOW          2021             TV-MA
# 5796                       The Big Day  SHOW          2021             TV-MA
#
# ...

# %%
# Drop run_time column from data set
df_orig.drop(columns = ['runtime'])
# Out:
#                                  title  type  release_year age_certification  \
# 5         Monty Python's Flying Circus  SHOW          1969             TV-14
# 29    Monty Python's Fliegender Zirkus  SHOW          1972             TV-MA
# 47                            Seinfeld  SHOW          1989             TV-PG
# 55                        Knight Rider  SHOW          1982             TV-PG
# 57                    Thomas & Friends  SHOW          1984              TV-Y
# ...                                ...   ...           ...               ...
# 5758          Abla Fahita: Drama Queen  SHOW          2021             TV-14
# 5768                    Christmas Flow  SHOW          2021             TV-MA
# 5770       Korean Cold Noodle Rhapsody  SHOW          2021             TV-PG
# 5785                     Pitta Kathalu  SHOW          2021             TV-MA
# 5796                       The Big Day  SHOW          2021             TV-MA
#
# ...

# %%
df_orig.isnull().sum()
# Out:
# title                   0
# type                    0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# dtype: int64

# %%
df_orig.head()
# Out:
#                                title  type  release_year age_certification  \
# 5       Monty Python's Flying Circus  SHOW          1969             TV-14
# 29  Monty Python's Fliegender Zirkus  SHOW          1972             TV-MA
# 47                          Seinfeld  SHOW          1989             TV-PG
# 55                      Knight Rider  SHOW          1982             TV-PG
# 57                  Thomas & Friends  SHOW          1984              TV-Y
#
#     runtime                                             genres  \
# 5        30                             ['comedy', 'european']
# 29       43                                         ['comedy']
# 47       24                                         ['comedy']
# 55       51              ['action', 'scifi', 'crime', 'drama']
# 57       10  ['family', 'comedy', 'music', 'action', 'anima...
#
#    production_countries  seasons    imdb_id  imdb_score  imdb_votes
# ...

# %%
df_orig.to_csv(path+"clean_data.csv")
