# %%
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import statsmodels.api as sm
import warnings


warnings.filterwarnings("ignore")

plt.style.use('fivethirtyeight')

# %%
df1= pd.read_csv(r"C:\Users\danie\Desktop\Dan\Career Foundry\Achievement Six\Netflix Movies and Shows\imdb_movies_shows.csv2nd_prep_data.csv")

# %%
df1.shape
# Out:
# (5558, 10)

# %%
# check the mean
df['release_year'].mean()
# Out:
# 2015.904282115869

# %%
# check the median
df['release_year'].median()
# Out:
# 2018.0

# %%
# check the max
df['release_year'].max()
# Out:
# 2022

# %%
# fill in missing values
df['release_year'] = df['release_year'].fillna(df['release_year'].median())

# %%
df['imdb_votes'] = df['imdb_votes'].fillna(df['imdb_votes'].median())

# %%
#create a subset 
sub2 = df[['release_year', 'imdb_votes']]

# %%
sub2.head(5)
# Out:
#    release_year  imdb_votes
# 0          1945      2471.0
# 1          1976    795222.0
# 2          1975    530877.0
# 3          1979    392419.0
# 4          1973    391942.0

# %%
sub2.shape
# Out:
# (5558, 2)

# %%
sub2.columns
# Out:
# Index(['release_year', 'imdb_votes'], dtype='object')

# %%
type(sub2)
# Out:
# pandas.core.frame.DataFrame

# %%
# Plot the data using matplotlib.

plt.figure(figsize=(15,5), dpi=100) # The dpi argument controls the quality of the visualization here. When it's set to 100,
# it will produce lower-than-standard quality, which is useful if, similar to this notebook, you'll have a lot of plots.
# A large number of plots will increase the size of the notebook, which could take more time to load and eat up a lot of RAM!

plt.plot(sub2)
